# %%
import re

def parse_best_so_far(file_path):
    best_so_far = []
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Regex para capturar as configurações best-so-far
    iteration_blocks = re.findall(
        r"Iteration \d+ of \d+.*?Best-so-far configuration:\s*(\d+).*?mean value:\s*([\d.]+).*?Description of the best-so-far configuration:\s*((?:.|\n)*?)#",
        content, re.MULTILINE | re.DOTALL
    )
    
    for config_id, mean_value, description in iteration_blocks:
        # Processar a descrição para extrair os parâmetros
        params = {}
        description_lines = description.strip().split("\n")
        
        # Corrigir o processamento da descrição
        for i in range(0, len(description_lines), 2):
            if i + 1 < len(description_lines):
                keys = description_lines[i].strip().split()
                values = description_lines[i + 1].strip().split()
                for key, value in zip(keys, values):
                    params[key] = value
        
        # Adicionar a iteração no formato desejado
        best_so_far.append({
            "config_id": config_id,
            "mean_value": float(mean_value),
            "parameters": params
        })
    
    return best_so_far

# Exemplo de uso
file_path = '/Users/jvmaues/Documents/Estudos/Mestrado/optimization/cvrp-cec/irace_files_HGS/log_j1/output_K3E1C10.txt'
result = parse_best_so_far(file_path)

# Exibindo o dicionário resultante

result
# Out:
# [{'config_id': '3',
#   'mean_value': 51789.14286,
#   'parameters': {'.ID.': '3',
#    'nbIterTraces': '3',
#    'nbGranular': '700',
#    'mu': '20',
#    'lambda': '20',
#    'nbElite': '60',
#    'nbClose': '5',
#    'nbIterPenaltyManagement': '3',
#    'targetFeasible': '150',
#    'penaltyIncrease': '0.3',
#    'penaltyDecrease': '1.3',
#    '.PARENT.': '3'}},
#  {'config_id': '3',
#   'mean_value': 68182.55556,
#   'parameters': {'.ID.': '3',
#    'nbIterTraces': '3',
#    'nbGranular': '700',
#    'mu': '20',
#    'lambda': '20',
#    'nbElite': '60',
#    'nbClose': '5',
#    'nbIterPenaltyManagement': '3',
#    'targetFeasible': '150',
#    'penaltyIncrease': '0.3',
#    'penaltyDecrease': '1.3',
#    '.PARENT.': '3'}},
#  {'config_id': '6',
#   'mean_value': 75932.27273,
#   'parameters': {'.ID.': '6',
#    'nbIterTraces': '6',
#    'nbGranular': '700',
#    'mu': '20',
#    'lambda': '30',
#    'nbElite': '20',
#    'nbClose': '5',
#    'nbIterPenaltyManagement': '6',
#    'targetFeasible': '100',
#    'penaltyIncrease': '0.4',
#    'penaltyDecrease': '1.2',
#    '.PARENT.': '6'}},
#  {'config_id': '6',
#   'mean_value': 71900.08333,
#   'parameters': {'.ID.': '6',
#    'nbIterTraces': '6',
#    'nbGranular': '700',
#    'mu': '20',
#    'lambda': '30',
#    'nbElite': '20',
#    'nbClose': '5',
#    'nbIterPenaltyManagement': '6',
#    'targetFeasible': '100',
#    'penaltyIncrease': '0.4',
#    'penaltyDecrease': '1.2',
#    '.PARENT.': '6'}},
#  {'config_id': '6',
#   'mean_value': 68449.84615,
#   'parameters': {'.ID.': '6',
#    'nbIterTraces': '6',
#    'nbGranular': '700',
#    'mu': '20',
#    'lambda': '30',
#    'nbElite': '20',
#    'nbClose': '5',
#    'nbIterPenaltyManagement': '6',
#    'targetFeasible': '100',
#    'penaltyIncrease': '0.4',
#    'penaltyDecrease': '1.2',
#    '.PARENT.': '6'}}]

# %%
import os
import re

def parse_best_so_far(file_path):
    """
    Parse the best-so-far configurations from a single file.
    """
    best_so_far = []
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Regex para capturar as configurações best-so-far
    iteration_blocks = re.findall(
        r"Iteration \d+ of \d+.*?Best-so-far configuration:\s*(\d+).*?mean value:\s*([\d.]+).*?Description of the best-so-far configuration:\s*((?:.|\n)*?)#",
        content, re.MULTILINE | re.DOTALL
    )
    
    for config_id, mean_value, description in iteration_blocks:
        # Processar a descrição para extrair os parâmetros
        params = {}
        description_lines = description.strip().split("\n")
        
        for i in range(0, len(description_lines), 2):
            if i + 1 < len(description_lines):
                keys = description_lines[i].strip().split()
                values = description_lines[i + 1].strip().split()
                for key, value in zip(keys, values):
                    params[key] = value
        
        # Adicionar o resultado no formato desejado
        best_so_far.append({
            "config_id": config_id,
            "mean_value": float(mean_value),
            "parameters": params,
            "name": os.path.basename(file_path).split(".")[0].split("_")[1]
        })
    
    menor_dicionario = min(best_so_far, key=lambda d: d["mean_value"])
    # # Adicionar a chave "name" com o nome base do arquivo
    # for entry in best_so_far:
    #     entry["name"] = os.path.basename(file_path).split(".")[0].split("_")[1]
    
    return menor_dicionario

def parse_directory(directory_path):
    """
    Parse all files in a directory for best-so-far configurations.
    """
    results = []
    for file_name in os.listdir(directory_path):
        file_path = os.path.join(directory_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith(".txt"):
            results.append(parse_best_so_far(file_path))
    return results

# # Exemplo de uso
directory_path = '/Users/jvmaues/Documents/Estudos/Mestrado/optimization/cvrp-cec/irace_files_HGS/log_j1/'
results = parse_directory(directory_path)

# print(results)

# Exibindo os resultados
for result in results:
    print(result)

# result = parse_best_so_far(directory_path)
# result
# Out:
# {'config_id': '4', 'mean_value': 46084.75, 'parameters': {'.ID.': '4', 'nbIterTraces': '4', 'nbGranular': '500', 'mu': '20', 'lambda': '20', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '4', 'targetFeasible': '50', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '4'}, 'name': 'K7E2C10J1'}
# {'config_id': '3', 'mean_value': 38393.66667, 'parameters': {'.ID.': '3', 'nbIterTraces': '3', 'nbGranular': '700', 'mu': '20', 'lambda': '20', 'nbElite': '60', 'nbClose': '5', 'nbIterPenaltyManagement': '3', 'targetFeasible': '150', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '3'}, 'name': 'K7E3C10J1'}
# {'config_id': '5', 'mean_value': 12908.875, 'parameters': {'.ID.': '5', 'nbIterTraces': '5', 'nbGranular': '500', 'mu': '15', 'lambda': '20', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '5', 'targetFeasible': '150', 'penaltyIncrease': '0.4', 'penaltyDecrease': '1.4', '.PARENT.': '5'}, 'name': 'K7E5C15J1'}
# {'config_id': '8', 'mean_value': 54543.9, 'parameters': {'.ID.': '8', 'nbIterTraces': '8', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '8', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.4', '.PARENT.': '8'}, 'name': 'K7E4C15J1'}
# {'config_id': '2', 'mean_value': 28658.33333, 'parameters': {'.ID.': '2', 'nbIterTraces': '2', 'nbGranular': '700', 'mu': '15', 'lambda': '20', 'nbElite': '60', 'nbClose': '7', 'nbIterPenaltyManagement': '2', 'targetFeasible': '150', 'penaltyIncrease': '0.5', 'penaltyDecrease': '1.3', '.PARENT.': '2'}, 'name': 'K7E7C18J1'}
# {'config_id': '9', 'mean_value': 52556.07692, 'parameters': {'.ID.': '9', 'nbIterTraces': '9', 'nbGranular': '700', 'mu': '25', 'lambda': '30', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '9', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '9'}, 'name': 'K7E6C18J1'}
# {'config_id': '7', 'mean_value': 41010.0, 'parameters': {'.ID.': '7', 'nbIterTraces': '7', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '7', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.3', '.PARENT.': '7'}, 'name': 'K5E3C15J1'}
# {'config_id': '6', 'mean_value': 45089.66667, 'parameters': {'.ID.': '6', 'nbIterTraces': '6', 'nbGranular': '500', 'mu': '25', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '6', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.3', '.PARENT.': '6'}, 'name': 'K5E2C15J1'}
# {'config_id': '3', 'mean_value': 51789.14286, 'parameters': {'.ID.': '3', 'nbIterTraces': '3', 'nbGranular': '700', 'mu': '20', 'lambda': '20', 'nbElite': '60', 'nbClose': '5', 'nbIterPenaltyManagement': '3', 'targetFeasible': '150', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '3'}, 'name': 'K3E1C10J1'}
# {'config_id': '11', 'mean_value': 55529.81818, 'parameters': {'.ID.': '11', 'nbIterTraces': '11', 'nbGranular': '700', 'mu': '25', 'lambda': '20', 'nbElite': '60', 'nbClose': '7', 'nbIterPenaltyManagement': '11', 'targetFeasible': '100', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.4', '.PARENT.': '11'}, 'name': 'K5E4C10J1'}
# {'config_id': '4', 'mean_value': 48086.33333, 'parameters': {'.ID.': '4', 'nbIterTraces': '4', 'nbGranular': '500', 'mu': '20', 'lambda': '20', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '4', 'targetFeasible': '50', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '4'}, 'name': 'K5E5C10J1'}
# {'config_id': '8', 'mean_value': 52717.81818, 'parameters': {'.ID.': '8', 'nbIterTraces': '8', 'nbGranular': '700', 'mu': '15', 'lambda': '20', 'nbElite': '60', 'nbClose': '7', 'nbIterPenaltyManagement': '8', 'targetFeasible': '150', 'penaltyIncrease': '0.5', 'penaltyDecrease': '1.2', '.PARENT.': '8'}, 'name': 'K5E1C18J1'}
# {'config_id': '10', 'mean_value': 66178.81818, 'parameters': {'.ID.': '10', 'nbIterTraces': '10', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '10', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.4', '.PARENT.': '10'}, 'name': 'K5E4C15J1'}
# {'config_id': '6', 'mean_value': 19530.0, 'parameters': {'.ID.': '6', 'nbIterTraces': '6', 'nbGranular': '500', 'mu': '25', 'lambda': '20', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '6', 'targetFeasible': '100', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.3', '.PARENT.': '6'}, 'name': 'K5E5C15J1'}
# {'config_id': '1', 'mean_value': 34521.25, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '1'}, 'name': 'K3E1C15J1'}
# {'config_id': '3', 'mean_value': 27925.81818, 'parameters': {'.ID.': '3', 'nbIterTraces': '3', 'nbGranular': '700', 'mu': '20', 'lambda': '20', 'nbElite': '60', 'nbClose': '5', 'nbIterPenaltyManagement': '3', 'targetFeasible': '150', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '3'}, 'name': 'K5E3C10J1'}
# {'config_id': '4', 'mean_value': 47005.3, 'parameters': {'.ID.': '4', 'nbIterTraces': '4', 'nbGranular': '700', 'mu': '25', 'lambda': '20', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '4', 'targetFeasible': '100', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.4', '.PARENT.': '4'}, 'name': 'K5E2C10J1'}
# {'config_id': '5', 'mean_value': 25011.375, 'parameters': {'.ID.': '5', 'nbIterTraces': '5', 'nbGranular': '700', 'mu': '25', 'lambda': '30', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '5', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '5'}, 'name': 'K3E2C18J1'}
# {'config_id': '10', 'mean_value': 61289.46154, 'parameters': {'.ID.': '10', 'nbIterTraces': '10', 'nbGranular': '700', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '10', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '10'}, 'name': 'K3E3C18J1'}
# {'config_id': '7', 'mean_value': 24847.22222, 'parameters': {'.ID.': '7', 'nbIterTraces': '7', 'nbGranular': '700', 'mu': '15', 'lambda': '20', 'nbElite': '40', 'nbClose': '3', 'nbIterPenaltyManagement': '7', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '7'}, 'name': 'K7E5C10J1'}
# {'config_id': '2', 'mean_value': 31665.57143, 'parameters': {'.ID.': '2', 'nbIterTraces': '2', 'nbGranular': '700', 'mu': '20', 'lambda': '30', 'nbElite': '40', 'nbClose': '7', 'nbIterPenaltyManagement': '2', 'targetFeasible': '50', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.2', '.PARENT.': '2'}, 'name': 'K7E4C10J1'}
# {'config_id': '5', 'mean_value': 38826.11111, 'parameters': {'.ID.': '5', 'nbIterTraces': '5', 'nbGranular': '500', 'mu': '15', 'lambda': '20', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '5', 'targetFeasible': '150', 'penaltyIncrease': '0.4', 'penaltyDecrease': '1.4', '.PARENT.': '5'}, 'name': 'K7E2C15J1'}
# {'config_id': '8', 'mean_value': 57446.45455, 'parameters': {'.ID.': '8', 'nbIterTraces': '8', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '8', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '8'}, 'name': 'K7E3C15J1'}
# {'config_id': '1', 'mean_value': 31957.5, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K7E1C18J1'}
# {'config_id': '1', 'mean_value': 31269.16667, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K5E2C18J1'}
# {'config_id': '4', 'mean_value': 37280.76923, 'parameters': {'.ID.': '4', 'nbIterTraces': '4', 'nbGranular': '500', 'mu': '15', 'lambda': '20', 'nbElite': '20', 'nbClose': '3', 'nbIterPenaltyManagement': '4', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '4'}, 'name': 'K5E3C18J1'}
# {'config_id': '9', 'mean_value': 20404.36364, 'parameters': {'.ID.': '9', 'nbIterTraces': '9', 'nbGranular': '500', 'mu': '15', 'lambda': '20', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '9', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.4', '.PARENT.': '9'}, 'name': 'K5E1C15J1'}
# {'config_id': '7', 'mean_value': 88445.0, 'parameters': {'.ID.': '7', 'nbIterTraces': '7', 'nbGranular': '500', 'mu': '15', 'lambda': '20', 'nbElite': '40', 'nbClose': '5', 'nbIterPenaltyManagement': '7', 'targetFeasible': '50', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '7'}, 'name': 'K3E3C10J1'}
# {'config_id': '4', 'mean_value': 25119.27273, 'parameters': {'.ID.': '4', 'nbIterTraces': '4', 'nbGranular': '500', 'mu': '20', 'lambda': '25', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '4', 'targetFeasible': '150', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.3', '.PARENT.': '4'}, 'name': 'K3E2C10J1'}
# {'config_id': '5', 'mean_value': 37548.25, 'parameters': {'.ID.': '5', 'nbIterTraces': '5', 'nbGranular': '700', 'mu': '25', 'lambda': '30', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '5', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '5'}, 'name': 'K7E4C18J1'}
# {'config_id': '8', 'mean_value': 27132.83333, 'parameters': {'.ID.': '8', 'nbIterTraces': '8', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '8', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '8'}, 'name': 'K7E5C18J1'}
# {'config_id': '9', 'mean_value': 55143.66667, 'parameters': {'.ID.': '9', 'nbIterTraces': '9', 'nbGranular': '700', 'mu': '25', 'lambda': '20', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '9', 'targetFeasible': '150', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '9'}, 'name': 'K7E1C10J1'}
# {'config_id': '1', 'mean_value': 24375.33333, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '1'}, 'name': 'K7E6C15J1'}
# {'config_id': '1', 'mean_value': 25991.66667, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '1'}, 'name': 'K7E7C15J1'}
# {'config_id': '1', 'mean_value': 24072.0, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K7E3C18J1'}
# {'config_id': '1', 'mean_value': 52661.3, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K7E2C18J1'}
# {'config_id': '3', 'mean_value': 23106.45455, 'parameters': {'.ID.': '3', 'nbIterTraces': '3', 'nbGranular': '700', 'mu': '20', 'lambda': '20', 'nbElite': '60', 'nbClose': '5', 'nbIterPenaltyManagement': '3', 'targetFeasible': '150', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '3'}, 'name': 'K7E6C10J1'}
# {'config_id': '7', 'mean_value': 20510.11111, 'parameters': {'.ID.': '7', 'nbIterTraces': '7', 'nbGranular': '500', 'mu': '15', 'lambda': '25', 'nbElite': '40', 'nbClose': '5', 'nbIterPenaltyManagement': '7', 'targetFeasible': '100', 'penaltyIncrease': '0.4', 'penaltyDecrease': '1.4', '.PARENT.': '7'}, 'name': 'K7E7C10J1'}
# {'config_id': '10', 'mean_value': 31245.54545, 'parameters': {'.ID.': '10', 'nbIterTraces': '10', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '10', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '10'}, 'name': 'K7E1C15J1'}
# {'config_id': '1', 'mean_value': 16871.88889, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K3E1C18J1'}
# {'config_id': '10', 'mean_value': 39634.66667, 'parameters': {'.ID.': '10', 'nbIterTraces': '10', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '10', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.3', '.PARENT.': '10'}, 'name': 'K5E5C18J1'}
# {'config_id': '1', 'mean_value': 32349.16667, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '250', 'mu': '25', 'lambda': '25', 'nbElite': '20', 'nbClose': '5', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.2', '.PARENT.': '1'}, 'name': 'K5E4C18J1'}
# {'config_id': '1', 'mean_value': 38311.0, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '1'}, 'name': 'K3E3C15J1'}
# {'config_id': '1', 'mean_value': 44846.44444, 'parameters': {'.ID.': '1', 'nbIterTraces': '1', 'nbGranular': '500', 'mu': '15', 'lambda': '30', 'nbElite': '20', 'nbClose': '7', 'nbIterPenaltyManagement': '1', 'targetFeasible': '100', 'penaltyIncrease': '0.3', 'penaltyDecrease': '1.4', '.PARENT.': '1'}, 'name': 'K3E2C15J1'}
# {'config_id': '2', 'mean_value': 30280.0, 'parameters': {'.ID.': '2', 'nbIterTraces': '2', 'nbGranular': '700', 'mu': '20', 'lambda': '30', 'nbElite': '40', 'nbClose': '7', 'nbIterPenaltyManagement': '2', 'targetFeasible': '50', 'penaltyIncrease': '0.2', 'penaltyDecrease': '1.2', '.PARENT.': '2'}, 'name': 'K5E1C10J1'}

# %%
import pandas as pd

# Transformando a lista de dicionários em um DataFrame
df = pd.DataFrame([{**{"name": d["name"]}, **d["parameters"]} for d in results])

df
# Out:
#          name .ID. nbIterTraces nbGranular  mu lambda nbElite nbClose  \
# 0   K7E2C10J1    4            4        500  20     20      20       5
# 1   K7E3C10J1    3            3        700  20     20      60       5
# 2   K7E5C15J1    5            5        500  15     20      20       7
# 3   K7E4C15J1    8            8        500  15     30      20       7
# 4   K7E7C18J1    2            2        700  15     20      60       7
# 5   K7E6C18J1    9            9        700  25     30      20       5
# 6   K5E3C15J1    7            7        500  15     30      20       7
# 7   K5E2C15J1    6            6        500  25     30      20       7
# 8   K3E1C10J1    3            3        700  20     20      60       5
# 9   K5E4C10J1   11           11        700  25     20      60       7
# 10  K5E5C10J1    4            4        500  20     20      20       5
# 11  K5E1C18J1    8            8        700  15     20      60       7
# 12  K5E4C15J1   10           10        500  15     30      20       7
# 13  K5E5C15J1    6            6        500  25     20      20       7
# 14  K3E1C15J1    1            1        500  15     30      20       7
# 15  K5E3C10J1    3            3        700  20     20      60       5
# 16  K5E2C10J1    4            4        700  25     20      20       7
# 17  K3E2C18J1    5            5        700  25     30      20       5
# 18  K3E3C18J1   10           10        700  15     30      20       5
# 19  K7E5C10J1    7            7        700  15     20      40       3
# 20  K7E4C10J1    2            2        700  20     30      40       7
# 21  K7E2C15J1    5            5        500  15     20      20       7
# 22  K7E3C15J1    8            8        500  15     30      20       7
# 23  K7E1C18J1    1            1        250  25     25      20       5
# 24  K5E2C18J1    1            1        250  25     25      20       5
# 25  K5E3C18J1    4            4        500  15     20      20       3
# 26  K5E1C15J1    9            9        500  15     20      20       5
# 27  K3E3C10J1    7            7        500  15     20      40       5
# 28  K3E2C10J1    4            4        500  20     25      20       7
# 29  K7E4C18J1    5            5        700  25     30      20       5
# 30  K7E5C18J1    8            8        250  25     25      20       5
# 31  K7E1C10J1    9            9        700  25     20      20       5
# 32  K7E6C15J1    1            1        500  15     30      20       7
# 33  K7E7C15J1    1            1        500  15     30      20       7
# 34  K7E3C18J1    1            1        250  25     25      20       5
# 35  K7E2C18J1    1            1        250  25     25      20       5
# 36  K7E6C10J1    3            3        700  20     20      60       5
# 37  K7E7C10J1    7            7        500  15     25      40       5
# 38  K7E1C15J1   10           10        500  15     30      20       7
# 39  K3E1C18J1    1            1        250  25     25      20       5
# 40  K5E5C18J1   10           10        250  25     25      20       7
# 41  K5E4C18J1    1            1        250  25     25      20       5
# 42  K3E3C15J1    1            1        500  15     30      20       7
# 43  K3E2C15J1    1            1        500  15     30      20       7
# 44  K5E1C10J1    2            2        700  20     30      40       7
#
#    nbIterPenaltyManagement targetFeasible penaltyIncrease penaltyDecrease  \
# 0                        4             50             0.3             1.2
# 1                        3            150             0.3             1.3
# 2                        5            150             0.4             1.4
# 3                        8            150             0.2             1.4
# 4                        2            150             0.5             1.3
# 5                        9            100             0.3             1.3
# 6                        7            150             0.2             1.3
# 7                        6            150             0.2             1.3
# 8                        3            150             0.3             1.3
# 9                       11            100             0.2             1.4
# 10                       4             50             0.3             1.2
# 11                       8            150             0.5             1.2
# 12                      10            150             0.2             1.4
# 13                       6            100             0.2             1.3
# 14                       1            100             0.3             1.4
# 15                       3            150             0.3             1.3
# 16                       4            100             0.2             1.4
# 17                       5            100             0.3             1.2
# 18                      10            100             0.3             1.2
# 19                       7            100             0.3             1.3
# 20                       2             50             0.2             1.2
# 21                       5            150             0.4             1.4
# 22                       8            100             0.3             1.3
# 23                       1            100             0.3             1.2
# 24                       1            100             0.3             1.2
# 25                       4            100             0.3             1.2
# 26                       9            150             0.2             1.4
# 27                       7             50             0.3             1.2
# 28                       4            150             0.2             1.3
# 29                       5            100             0.3             1.2
# 30                       8            100             0.3             1.2
# 31                       9            150             0.3             1.4
# 32                       1            100             0.3             1.4
# 33                       1            100             0.3             1.4
# 34                       1            100             0.3             1.2
# 35                       1            100             0.3             1.2
# 36                       3            150             0.3             1.3
# 37                       7            100             0.4             1.4
# 38                      10            100             0.3             1.4
# 39                       1            100             0.3             1.2
# 40                      10            100             0.3             1.3
# 41                       1            100             0.3             1.2
# 42                       1            100             0.3             1.4
# 43                       1            100             0.3             1.4
# 44                       2             50             0.2             1.2
#
#    .PARENT.
# 0         4
# 1         3
# 2         5
# 3         8
# 4         2
# 5         9
# 6         7
# 7         6
# 8         3
# 9        11
# 10        4
# 11        8
# 12       10
# 13        6
# 14        1
# 15        3
# 16        4
# 17        5
# 18       10
# 19        7
# 20        2
# 21        5
# 22        8
# 23        1
# 24        1
# 25        4
# 26        9
# 27        7
# 28        4
# 29        5
# 30        8
# 31        9
# 32        1
# 33        1
# 34        1
# 35        1
# 36        3
# 37        7
# 38       10
# 39        1
# 40       10
# 41        1
# 42        1
# 43        1
# 44        2

# %%
import os

# Diretório contendo os arquivos .txt
diretorio = "/Users/jvmaues/Documents/Estudos/Mestrado/optimization/cvrp-cec/irace_files_HGS/log_j3"

# String a ser acrescentada no final do nome do arquivo
sufixo = "J3"

# Iterar sobre todos os arquivos no diretório
for arquivo in os.listdir(diretorio):
    if arquivo.endswith(".txt"):  # Verifica se o arquivo é .txt
        caminho_antigo = os.path.join(diretorio, arquivo)
        # Adicionar o sufixo antes da extensão
        novo_nome = f"{os.path.splitext(arquivo)[0]}{sufixo}.txt"
        caminho_novo = os.path.join(diretorio, novo_nome)
        
        # Renomear o arquivo
        os.rename(caminho_antigo, caminho_novo)

print("Arquivos renomeados com sucesso!")
# Out:
# Arquivos renomeados com sucesso!

# %%
import os

# Diretório base onde estão os arquivos .txt
diretorio_base = "/Users/jvmaues/Documents/Estudos/Mestrado/optimization/cvrp-cec/irace_files_HGS/J3"

# String a ser acrescentada ao nome dos arquivos
sufixo = "J3"

# Percorrer diretórios e subdiretórios
for raiz, _, arquivos in os.walk(diretorio_base):
    for arquivo in arquivos:
        if arquivo.endswith(".txt"):  # Verifica se é um arquivo .txt
            caminho_antigo = os.path.join(raiz, arquivo)
            novo_nome = f"{os.path.splitext(arquivo)[0]}{sufixo}.txt"
            caminho_novo = os.path.join(raiz, novo_nome)
            
            # Renomeia o arquivo
            os.rename(caminho_antigo, caminho_novo)

print("Todos os arquivos foram renomeados com sucesso!")
# Out:
# Todos os arquivos foram renomeados com sucesso!

# %%
import os
import re
from collections import defaultdict

def parse_best_so_far(file_path):
    """
    Parse the best-so-far configurations from a single file.
    """
    best_so_far = []
    with open(file_path, 'r') as file:
        content = file.read()
    
    # Regex para capturar as configurações best-so-far
    iteration_blocks = re.findall(
        r"Iteration \d+ of \d+.*?Best-so-far configuration:\s*(\d+).*?mean value:\s*([\d.]+).*?Description of the best-so-far configuration:\s*((?:.|\n)*?)#",
        content, re.MULTILINE | re.DOTALL
    )
    
    for config_id, mean_value, description in iteration_blocks:
        # Processar a descrição para extrair os parâmetros
        params = {}
        description_lines = description.strip().split("\n")
        
        for i in range(0, len(description_lines), 2):
            if i + 1 < len(description_lines):
                keys = description_lines[i].strip().split()
                values = description_lines[i + 1].strip().split()
                for key, value in zip(keys, values):
                    params[key] = value
        
        # Adicionar o resultado no formato desejado
        best_so_far.append({
            "config_id": config_id,
            "mean_value": float(mean_value),
            "parameters": params
        })
    
    # Adicionar a chave "name" com o nome base do arquivo
    for entry in best_so_far:
        entry["name"] = os.path.basename(file_path).split(".")[0]
    
    return best_so_far

def parse_directory_with_scenarios(directory_path):
    """
    Parse all files in a directory for best-so-far configurations and include scenario enumeration.
    """
    results = []
    scenarios = defaultdict(list)
    
    # Agrupar arquivos por cenários com base no número após 'K'
    for file_name in os.listdir(directory_path):
        if file_name.endswith(".txt"):
            match = re.match(r"K(\d+)E(\d+)C\d+", file_name)
            if match:
                k_value, e_value = match.groups()
                scenario_id = f"K{k_value}"
                scenarios[scenario_id].append(file_name)
    
    # Processar os arquivos agrupados por cenário
    for scenario_id, files in scenarios.items():
        for file_name in files:
            file_path = os.path.join(directory_path, file_name)
            if os.path.isfile(file_path):
                parsed_data = parse_best_so_far(file_path)
                for entry in parsed_data:
                    entry["scenario"] = scenario_id  # Adiciona o identificador do cenário
                results.extend(parsed_data)
    
    return results

# Exemplo de uso
directory_path = '/Users/jvmaues/Documents/Estudos/Mestrado/optimization/cvrp-cec/irace_files_HGS/log_j1'
results = parse_directory_with_scenarios(directory_path)

# Exibindo os resultados
for result in results:
    print(result)

# %%
import random
import pandas as pd

# Função para gerar dados sintéticos
def generate_synthetic_data():
    scenarios = [
        ["k3E1C10", "k3E2C10", "k3E3C10"],
        ["k3E1C15", "k3E2C15", "k3E3C15"],
        ["k3E1C18", "k3E2C18", "k3E3C18"]
    ]

    synthetic_data = []
    instance_id = 1  # Identificador incremental simples para cada cenário completo

    for scenario_group in scenarios:
        for enterprise_clients in scenario_group:
            for config_id in range(1, 6):  # Máximo de 5 config_id por empresa
                config = {
                    "instance": instance_id,  # ID único para o cenário completo
                    "enterprise_clients": enterprise_clients,  # Ex.: k3E1C10
                    "config_id": f"config_{config_id}",
                    "nbIterTraces": random.randint(500, 1000),
                    "nbGranular": random.randint(10, 30),
                    "mu": random.randint(10, 50),
                    "lambda": random.randint(15, 50),
                    "nbElite": random.randint(2, 10),
                    "nbClose": random.randint(2, 10),
                    "nbIterPenaltyManagement": random.randint(30, 200),
                    "targetFeasible": round(random.uniform(0.1, 0.9), 2),
                    "penaltyIncrease": round(random.uniform(1.0, 2.0), 2),
                    "penaltyDecrease": round(random.uniform(0.5, 0.9), 2)
                }
                synthetic_data.append(config)
        instance_id += 1  # Incrementa apenas após finalizar todas as empresas do mesmo cenário
    
    return synthetic_data

# Gerar dados sintéticos
data = generate_synthetic_data()

# Converter para DataFrame para visualização e manipulação
df = pd.DataFrame(data)

# Salvar os dados gerados para análise futura (opcional)
df.to_csv("synthetic_data.csv", index=False)

# Exibir os dados gerados
df
# Out:
#     instance enterprise_clients config_id  nbIterTraces  nbGranular  mu  \
# 0          1            k3E1C10  config_1           927          25  11
# 1          1            k3E1C10  config_2           991          10  29
# 2          1            k3E1C10  config_3           518          26  30
# 3          1            k3E1C10  config_4           503          11  27
# 4          1            k3E1C10  config_5           757          30  13
# 5          1            k3E2C10  config_1           732          21  22
# 6          1            k3E2C10  config_2           523          10  21
# 7          1            k3E2C10  config_3           690          10  37
# 8          1            k3E2C10  config_4           946          12  33
# 9          1            k3E2C10  config_5           871          25  20
# 10         1            k3E3C10  config_1           659          26  17
# 11         1            k3E3C10  config_2           887          22  10
# 12         1            k3E3C10  config_3           959          26  24
# 13         1            k3E3C10  config_4           741          10  45
# 14         1            k3E3C10  config_5           853          16  19
# 15         2            k3E1C15  config_1           941          16  22
# 16         2            k3E1C15  config_2           512          27  40
# 17         2            k3E1C15  config_3           734          14  40
# 18         2            k3E1C15  config_4           616          28  34
# 19         2            k3E1C15  config_5           864          11  44
# 20         2            k3E2C15  config_1           848          29  18
# 21         2            k3E2C15  config_2           954          20  42
# 22         2            k3E2C15  config_3           641          11  28
# 23         2            k3E2C15  config_4           620          19  11
# 24         2            k3E2C15  config_5           791          18  21
# 25         2            k3E3C15  config_1           789          22  15
# 26         2            k3E3C15  config_2           605          28  23
# 27         2            k3E3C15  config_3           545          16  11
# 28         2            k3E3C15  config_4           966          17  25
# 29         2            k3E3C15  config_5           520          12  40
# 30         3            k3E1C18  config_1           950          18  40
# 31         3            k3E1C18  config_2           684          20  47
# 32         3            k3E1C18  config_3           580          13  30
# 33         3            k3E1C18  config_4           850          20  29
# 34         3            k3E1C18  config_5           770          20  28
# 35         3            k3E2C18  config_1           603          16  13
# 36         3            k3E2C18  config_2           953          19  28
# 37         3            k3E2C18  config_3           735          26  26
# 38         3            k3E2C18  config_4           934          30  29
# 39         3            k3E2C18  config_5           720          19  35
# 40         3            k3E3C18  config_1           749          29  44
# 41         3            k3E3C18  config_2           615          28  32
# 42         3            k3E3C18  config_3           631          15  37
# 43         3            k3E3C18  config_4           827          11  16
# 44         3            k3E3C18  config_5           986          12  23
#
#     lambda  nbElite  nbClose  nbIterPenaltyManagement  targetFeasible  \
# 0       21        8        7                      123            0.26
# 1       25        4        6                      155            0.22
# 2       49        5        7                      143            0.66
# 3       47       10        7                      162            0.51
# 4       31        9        5                      182            0.34
# 5       49        4        2                       88            0.54
# 6       24        8        2                      105            0.32
# 7       45        9        2                      145            0.22
# 8       50        8        3                      105            0.11
# 9       23       10        3                       52            0.24
# 10      45        7        3                       53            0.44
# 11      43        5        4                      113            0.31
# 12      41        6        2                       63            0.74
# 13      40        3        4                      137            0.21
# 14      42        8        8                      123            0.32
# 15      23        5        3                      113            0.73
# 16      47        8        6                      169            0.61
# 17      15        4        3                       62            0.22
# 18      44        6        3                       72            0.89
# 19      35        6        2                      157            0.42
# 20      41        7        8                       70            0.19
# 21      29       10        3                      199            0.75
# 22      19        9        4                      137            0.87
# 23      19        7        6                       91            0.15
# 24      39        2        2                       93            0.82
# 25      29        5        4                      127            0.68
# 26      49        3        3                       89            0.69
# 27      16        2        9                      108            0.26
# 28      15       10       10                       82            0.32
# 29      18        7        5                       82            0.64
# 30      15        6        4                       78            0.47
# 31      16        5        2                      138            0.40
# 32      20        6       10                       92            0.78
# 33      24        9        2                       81            0.60
# 34      17        3        9                       38            0.35
# 35      16        7        8                      192            0.89
# 36      34        2        4                      120            0.80
# 37      39        6        2                      139            0.54
# 38      15        3        8                       63            0.34
# 39      21        2        7                      189            0.71
# 40      26        4       10                      126            0.28
# 41      49        5        4                       34            0.50
# 42      29       10        8                      197            0.12
# 43      37        7        3                      108            0.38
# 44      33        2        7                      141            0.53
#
#     penaltyIncrease  penaltyDecrease
# 0              1.37             0.88
# 1              1.38             0.70
# 2              1.09             0.86
# 3              1.59             0.69
# 4              1.18             0.74
# 5              1.77             0.55
# 6              1.41             0.80
# 7              1.63             0.56
# 8              1.36             0.67
# 9              1.23             0.51
# 10             1.22             0.73
# 11             1.81             0.67
# 12             1.65             0.52
# 13             1.93             0.69
# 14             1.74             0.65
# 15             1.71             0.71
# 16             1.47             0.68
# 17             1.92             0.66
# 18             1.02             0.65
# 19             1.36             0.60
# 20             1.75             0.68
# 21             1.23             0.61
# 22             1.50             0.73
# 23             1.93             0.51
# 24             1.55             0.76
# 25             1.59             0.54
# 26             1.41             0.69
# 27             1.64             0.79
# 28             1.78             0.59
# 29             1.05             0.58
# 30             1.99             0.74
# 31             1.98             0.57
# 32             1.15             0.87
# 33             1.87             0.55
# 34             1.22             0.70
# 35             1.72             0.66
# 36             1.10             0.64
# 37             1.93             0.86
# 38             1.47             0.62
# 39             1.33             0.71
# 40             1.76             0.60
# 41             1.67             0.88
# 42             1.14             0.77
# 43             1.49             0.65
# 44             1.07             0.73
